# %% [markdown]
# <br>
# <img src="https://th.bing.com/th/id/R.08d78d547107a48d03c6eb2f5141f09b?rik=KNbP59PpBQwWWQ&riu=http%3a%2f%2fensai.fr%2fwp-content%2fuploads%2f2019%2f05%2fEnsai-logo-300x282.png&ehk=aRCY7kpUQ083sCCZKjkAqzG8uUQFRF8IV%2b19WNjLSwQ%3d&risl=&pid=ImgRaw&r=0&sres=1&sresct=1" width=90px align="left">
# <div align="right" style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <strong>Enseignant :</strong> C. Mallart
# </div>
# <div align="right" style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <strong>Réalisé par :</strong> DIAKITE Gaoussou, SADIO Ndeye Salimata et ADUAYOM MESSAN Messan Daniel
# </div>
# <div align="right" style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px;">
#     <strong>Année :</strong> 2023/2024
# </div><br><br><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:32px;color:darkgreen">MASTÈRE DATA SCIENCE - CONNAISSANCE CLIENT</span></div><br>
# <div align="center"><span style="font-family:Lucida Caligraphy;font-size:28px;color:#e60000">Webmining et traitement du langage</span></div><br><br>
# <hr>
#
# <br>

# %% [markdown]
# <img src="https://th.bing.com/th/id/OIP.iPbwGuQCzB6z4PZNJkQJugHaJ4?rs=1&pid=ImgDetMain" width=90px align="left">
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>Projet Webmining NLP</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# >Dans ce projet, nous explorons l'application du traitement du langage naturel (NLP) dans le contexte du webmining. L'objectif est d'extraire et d'analyser des informations pertinentes à partir de sources en ligne, telles que les articles de nouvelles, pour découvrir des tendances, des relations entre entités nommées, et d'autres insights significatifs.
#
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">🔍 Étapes du Projet</h2>
#
# >1. **Acquisition traitement de données** : Collecte d'articles en ligne via des flux RSS.
# >2. **Extraction d'Informations** : Utilisation de spaCy pour l'analyse NLP, se concentrant sur les entités nommées.
# >3. **Analyse des Entités** : Identification des entités fréquentes et étude de leurs co-occurrences et contextes.
# >4. **Recherche de Relations Spécifiques** : Analyse des relations entre les entités pour une compréhension approfondie.
#
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">🎯 Objectifs du Projet</h2>
#
# >L'objectif principal est de développer une compréhension approfondie des techniques de NLP et leur application dans le webmining pour l'analyse de données et l'extraction d'informations.
#
# ><h2 style="color:#75DFC1; font-family: 'Arial', sans-serif;">💡 Utilité et Impact du Projet</h2>
#
# >Ce projet offre une opportunité d'appliquer des techniques avancées de NLP pour extraire des insights significatifs à partir de données textuelles en ligne, aidant ainsi à comprendre les tendances actuelles, les relations entre différentes entités, et à prendre des décisions basées sur des données probantes.
#
# <br/><br/><br/>

# %% [markdown]
# # Installation des packages et données nécessaires

# %%
# !wget https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/francetvinfo.json > /dev/null 2>&1
# !wget https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/tvinfo-sources.json > /dev/null 2>&1
# !pip install feedparser > /dev/null 2>&1
# !pip install newspaper3k > /dev/null 2>&1
# !python -m spacy download fr_core_news_md > /dev/null 2>&1

# %% [markdown]
# # LIBRAIRIES

# %%
import json
import feedparser as fp
import requests
import ssl

import feedparser as fp
import json
import ssl
import feedparser as fp
import json
import ssl
import requests

# Importer la bibliothèque spaCy et charger le modèle en français
import spacy
import spacy
import json
import requests
from collections import Counter
import spacy
import json
import requests
# Importez spaCy avec le modèle français
import spacy
import requests
import json
import feedparser as fp
import newspaper as np
import newspaper as np
import pandas as pd

# %% [markdown]
# # Acquisition de données par ecoute d’un flux RSS

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>Récupération des fichiers RSS : 1 - Lecture et Exploration de la Base de Données francetvinfo.json</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Cette section du notebook se concentre sur la première étape du projet : la lecture et l'exploration de la base de données existante <code>francetvinfo.json</code>. Cette base de données contient des articles récupérés à partir du flux RSS du site francetvinfo.fr. Le processus comprend :
# </p>
#
# <ul style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Chargement des Données :</strong> Le code commence par télécharger et charger le contenu du fichier JSON depuis l'URL fournie. Ceci est réalisé à l'aide de la bibliothèque <code>requests</code>.</li>
#     <li><strong>Extraction et Affichage des Articles :</strong> Une fois les données chargées, le code parcourt les premiers articles, limitant l'affichage à trois pour une vue d'ensemble. Pour chaque article, des informations telles que le titre, la date, l'auteur, la catégorie et un extrait du contenu sont affichées.</li>
# </ul>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Cette exploration initiale offre une compréhension de la structure des données et des types d'informations disponibles, ce qui est essentiel pour les étapes ultérieures d'analyse et de traitement des données.
# </p>

# %%
# Désactivation de la vérification SSL (si nécessaire)
ssl._create_default_https_context = ssl._create_unverified_context

# URL du fichier JSON de la base de données existante
url_json = "https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/francetvinfo.json"
data_json = requests.get(url_json).json()

# Afficher les trois premiers articles avec toutes les informations
for i, (link, article) in enumerate(data_json.items()):
    if i < 3:  # Limite à trois articles
        print(f"Titre: {article['title']}")
        print(f"Date: {article['date']}")
        print(f"Auteur(s): {', '.join(article['author']) if article['author'] else 'Non spécifié'}")
        print(f"Catégorie: {article['category']}")
        print(f"Lien: {link}")
        print(f"Contenu (extrait) : {article['content'][:400]}...")  # Affiche un extrait du contenu
        print(f"L'image de l'article : {article['image_link']}")
        print()  # Ajoute un espace entre les articles
    else:
        break

# Compter le nombre d'articles dans la base de données JSON
taille_base_articles = len(data_json)
print(f"Taille de la base de données des articles : {taille_base_articles} articles")

# Je transforme la base de donnée en DataFrame 
df_json= pd.DataFrame(data_json).T
df_json
# Out:
# Titre: Violences contre les maires : dans l'Eure, des élus apprennent à se défendre
# Date: 2020-01-19T16:31:16
# Auteur(s): Non spécifié
# Catégorie: france
# Lien: https://www.francetvinfo.fr/sante/prevention/eure-quand-les-elus-apprennent-a-se-defendre_3791635.html#xtor=RSS-3-[france]
# Contenu (extrait) : Beaucoup de maires et de secrétaires de mairie ont rencontré au cours de leurs mandats des problèmes de violence, essentiellement verbale. C'est le cas de Claire. Un jour, un homme est entré dans son bureau et a frappé très fort sur son bureau pour l'intimider. "J'ai réagi à l'instinct, j'ai essayé de discuter, mais ça s'est envenimé. Heureusement qu'une dame est arrivée à la permanence et a menac...
# L'image de l'article : https://www.francetvinfo.fr/image/75rt1bxrp-7049/1500/843/20799631.png
#
# Titre: VIDEO. Sur le dos d'un aigle pêcheur au-dessus du massif du Mont-Blanc dont les glaciers fondent aujourd'hui à vue d'œil
# Date: 2020-01-19T16:30:02
# Auteur(s): Non spécifié
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: red; font-size: 18px;">Commentaire sur la Structure de la Base de Données francetvinfo.json</h3>
#     <p>
#         L'examen de la base de données <code>francetvinfo.json</code> révèle une structure riche et détaillée, appropriée pour des analyses en traitement automatique du langage naturel (NLP). Chaque article est identifié par son URL et contient plusieurs champs d'information :
#     </p>
#     <ul>
#         <li><strong>Titre :</strong> Le titre de l'article, essentiel pour comprendre le sujet principal traité.</li>
#         <li><strong>Date :</strong> La date de publication, utile pour des analyses temporelles.</li>
#         <li><strong>Auteur(s) :</strong> Les auteurs de l'article, bien que souvent non spécifiés.</li>
#         <li><strong>Catégorie :</strong> La catégorie de l'article, permettant de classifier les articles selon leur thématique.</li>
#         <li><strong>Contenu :</strong> Le contenu de l'article, crucial pour toute analyse de texte.</li>
#         <li><strong>Lien :</strong> L'URL de l'article, permettant d'accéder directement à la source.</li>
#         <li><strong>Image de l'article :</strong> L'inclusion de l'image de l'article ajoute une dimension visuelle aux données, ce qui peut être utile pour des analyses d'images ou des extraits visuels dans les articles.</li>
#     </ul>
#     <p>
#         Ces données offrent une base solide pour des traitements NLP, tels que la reconnaissance d'entités nommées, l'analyse de sentiment, ou la classification thématique. La variété des champs permet une analyse multidimensionnelle des données.
#     </p>
#     <p>
#         Il est à noter qu'il existe un problème de récupération de texte répétitif lié à la pollution dans certains articles. Ce texte, sans rapport avec le contenu de l'article, semble être une sorte de vestige caché lors du scraping. Il serait important de mettre en place un traitement pour éliminer ces éléments indésirables lors de l'analyse des contenus d'articles.
#     </p>
# </div>

# %%
# Je visualise également les catégories des articles qui sont dans la base de données
print(df_json['category'].value_counts())
# Out:
# category
# europe      848
# france      788
# economie    461
# Name: count, dtype: int64

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1> Identification des informations disponibles dans le flux RSS Le monde.fr</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette partie du projet, nous nous concentrons sur l'analyse d'un flux RSS externe, spécifiquement celui du site <em>Le Monde.fr</em>. L'objectif est d'extraire et d'examiner les informations pertinentes disponibles dans ce flux. Le processus implique :
# </p>
#
# <ul style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Utilisation de la bibliothèque feedparser :</strong> Cette bibliothèque est utilisée pour parser le flux RSS et accéder aux données structurées qu'il contient.</li>
#     <li><strong>Récupération et Affichage des Données :</strong> Le code extrait le titre du flux, la date de publication et parcourt les articles, en se limitant à trois pour un aperçu. Chaque article est analysé pour en extraire le titre, la date de publication, le résumé, le lien, et d'autres informations disponibles comme le lien de l'image et le contenu supplémentaire.</li>
# </ul>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Cette analyse nous permet d'obtenir une vue d'ensemble des types d'articles et des informations qu'ils contiennent, ce qui est crucial pour des applications de veille géopolitique et/ou économique en NLP.
# </p>

# %%
# URL du flux RSS à analyser
url = "https://www.lemonde.fr/rss/une.xml"

# Récupération et analyse du flux RSS
data = fp.parse(url)

# Afficher les informations du flux RSS
print("Titre du flux RSS:", data.feed.title)
print("Date de publication du flux RSS:", data.feed.published)

# Itération sur quelques articles du flux RSS
for item in data.entries[:3]:  # Limite à trois articles pour l'exemple
    print("\nArticle:")
    print("Titre:", item.title)
    print("Date de publication:", item.published)
    print("Résumé:", item.summary)
    print("Lien:", item.link)
    if 'media_content' in item:
        print("Lien de l'image:", item.media_content[0]['url'])
    if 'content' in item:
        print("Contenu supplémentaire:", item.content[0]['value'])
# Out:
# Titre du flux RSS: Le Monde.fr - Actualités et Infos en France et dans le monde
# Date de publication du flux RSS: Fri, 16 Feb 2024 16:21:47 +0000
#
# Article:
# Titre: En direct, mort d’Alexeï Navalny en prison : condamnations internationales et accusations contre « le régime voyou » de Poutine
# Date de publication: Fri, 16 Feb 2024 17:16:32 +0100
# Résumé: Après l’annonce de la mort de l’activiste dans sa colonie pénitentiaire, de nombreux opposants russes, dont son épouse, Ioulia Navalnaïa, ont directement accusé le Kremlin. Les Etats-Unis, par la voix de sa vice-présidente, Kamala Harris, ont dénoncé « un nouveau signe de la brutalité » de Moscou. La diplomatie russe parle d’« accusations à l’emporte-pièce ».
# Lien: https://www.lemonde.fr/international/live/2024/02/16/en-direct-mort-d-alexei-navalny-en-prison-condamnations-internationales-et-accusations-contre-le-regime-voyou-de-poutine_6216904_3210.html
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: red; font-size: 18px;">Commentaire sur les Résultats de l'Analyse du Flux RSS</h3>
#     <p>
#         Les résultats de l'analyse du flux RSS fournissent des informations détaillées et structurées pour chaque article. Voici la structure des données extraites :
#     </p>
#     <ul>
#         <li><strong>Titre de l'Article :</strong> Fournit une vue d'ensemble du sujet traité dans l'article.</li>
#         <li><strong>Date de Publication :</strong> Indique le moment de la publication de l'article, utile pour l'analyse temporelle.</li>
#         <li><strong>Résumé :</strong> Offre un aperçu du contenu de l'article, utile pour une analyse préliminaire.</li>
#         <li><strong>Lien :</strong> Permet un accès direct à l'article pour une lecture approfondie.</li>
#         <li><strong>Lien de l'Image :</strong> Fournit un contexte visuel pour l'article.</li>
#         <li><strong>Contenu Supplémentaire :</strong> Offre des informations additionnelles qui peuvent enrichir l'analyse.</li>
#     </ul>
#     <p>
#         Cette structure bien organisée des données extraites du flux RSS est essentielle pour le traitement automatique du langage naturel (NLP), permettant des analyses telles que la reconnaissance d'entités nommées, l'analyse de sentiment et la catégorisation thématique.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>Lecture des données du flux RSS</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Voici une explication détaillée de la démarche que nous avons suivie pour analyser et extraire les données du flux RSS :
# </p>
#
# <ol style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Lien vers le fichier tvinfo-sources.json :</strong> Nous avons d'abord défini le lien vers le fichier tvinfo-sources.json, qui contient les URL des flux RSS que nous voulons analyser.</li>
#     <li><strong>Charger la liste des flux RSS :</strong> Nous avons utilisé la bibliothèque requests pour récupérer le contenu du fichier tvinfo-sources.json depuis son URL. Ensuite, nous avons converti le contenu JSON en une liste de sources.</li>
#     <li><strong>Lecture des données du flux RSS :</strong> Nous avons parcouru la liste des sources et pour chaque source, nous avons utilisé la bibliothèque feedparser pour lire les données du flux RSS correspondant.</li>
#     <li><strong>Récupération du premier article :</strong> Pour chaque flux RSS, nous avons récupéré le premier article s'il y en avait un.</li>
#     <li><strong>Extraction des informations de l'article :</strong> Nous avons extrait différentes informations de l'article telles que le titre, la description, la date de publication, le lien, la catégorie, le contenu et le lien de l'image (si disponibles).</li>
#     <li><strong>Affichage des informations de l'article :</strong> Enfin, nous avons affiché toutes les informations extraites de l'article.</li>
# </ol>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Cette démarche nous permet d'obtenir un aperçu des derniers articles de chaque source de flux RSS, ce qui est utile pour une analyse plus approfondie des informations.
# </p>

# %%
# Lien vers le fichier tvinfo-sources.json
tvinfo_sources_url = "https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/tvinfo-sources.json"

# Charger la liste des flux RSS depuis le lien tvinfo-sources.json
response_sources = requests.get(tvinfo_sources_url)
sources = json.loads(response_sources.text)

print(f'-------------------------------------------------Les flux RSS qui sont dans le fichier tvinfo-sources.json sont-------------------------------------------------')

print(sources)


print(f'-------------------------------------------------------Lecture des données du flux RSS-------------------------------------------------------------------------')

# Parcourir les flux RSS
for source_name, source_url in sources.items():
    # Lire les données du flux RSS
    data = fp.parse(source_url)
    
    # Récupérer le premier article du flux RSS (s'il y en a)
    if data.entries:
        item = data.entries[0]  # Prendre le premier article
        
        # Extraire les informations de l'article
        article = {
            "source": source_name,
            "title": item.title,
            "description": item.description,
            "pubDate": item.published,
            "link": item.link,
            "category": source_name,  # Vous pouvez modifier cette valeur en fonction de la source si nécessaire
            "content": item.content[0].value if "content" in item else "",  # Si le champ "content" est disponible
            "image_link": item.enclosures[0].url if "enclosures" in item and item.enclosures[0].type == "image/jpeg" else ""  # Si le champ "enclosures" est disponible et de type image/jpeg
        }
        
        # Afficher les informations de l'article
        print("Source:", article["source"])
        print("Titre:", article["title"])
        print("Description:", article["description"])
        print("Date de publication:", article["pubDate"])
        print("Lien:", article["link"])
        print("Catégorie:", article["category"])
        print("Contenu:", article["content"])
        print("Lien de l'image:", article["image_link"])
        print("\n")
# Out:
# -------------------------------------------------Les flux RSS qui sont dans le fichier tvinfo-sources.json sont-------------------------------------------------
# {'france': 'https://www.francetvinfo.fr/france.rss', 'europe': 'https://www.francetvinfo.fr/monde/europe.rss', 'economie': 'https://www.francetvinfo.fr/economie/entreprises.rss'}
# -------------------------------------------------------Lecture des données du flux RSS-------------------------------------------------------------------------
# Source: france
# Titre: Animaux : dans les coulisses du Parc des oiseaux durant l'hiver
# Description: Dans l'Ain, le Parc des oiseaux de Villars-les-Dombes est fermé durant l'hiver. Sur place, les soigneurs prennent soin des 2 000 oiseaux du parc.
# Date de publication: Fri, 16 Feb 2024 16:09:05 +0100
# Lien: https://www.francetvinfo.fr/animaux/animaux-dans-les-coulisses-du-parc-des-oiseaux-durant-l-hiver_6369964.html#xtor=RSS-3-[france]
# Catégorie: france
# Contenu:
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: red; font-size: 18px;">Commentaire sur le repérage des nouveaux articles</h3>
#     <p>
#         Les observations réalisées lors de l'analyse des flux RSS mettent en lumière deux aspects principaux :
#     </p>
#     <ul>
#         <li>
#             <strong>Fréquence de mise à jour des articles :</strong> Les articles figurant dans les flux RSS sont souvent très récents, datant généralement d'aujourd'hui, d'hier ou de l'avant-hier. Cela indique la nature évolutive des flux RSS, qui sont constamment actualisés pour afficher les dernières nouvelles.
#         </li>
#         <li>
#             <strong>Volatilité des articles dans le flux :</strong> Le contenu des flux RSS varie fréquemment, avec l'introduction de nouveaux articles et la disparition des plus anciens. Ce phénomène illustre la volatilité des flux RSS, où les articles plus anciens sont remplacés par de nouvelles publications.
#         </li>
#     </ul>
#     <p>
#         Cette analyse souligne l'importance de surveiller les flux RSS de manière régulière afin de détecter et de cataloguer les nouveaux articles. Toutefois, elle révèle également un défi pour le suivi à long terme des articles, car l'accès aux contenus peut se limiter aux publications récentes. Pour une exploration détaillée ou un archivage des informations, l'adoption de stratégies complémentaires, telles que le suivi des liens vers les articles complets ou la mise en œuvre d'un système d'archivage périodique, serait donc nécessaire.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>Scanner les Articles et Repérer les Nouveaux</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Après avoir obtenu les derniers articles de chaque source de flux RSS, nous avons procédé à la tâche de scanner les articles pour repérer ceux qui ne sont pas déjà présents dans la base de données. Voici comment nous avons accompli cette étape :
# </p>
#
# <ol style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Lien vers la base de données existante :</strong> Nous avons défini le lien vers la base de données existante, qui était stockée dans le fichier francetvinfo.json.</li>
#     <li><strong>Charger la base de données existante :</strong> Nous avons utilisé la bibliothèque requests pour récupérer le contenu du fichier francetvinfo.json depuis son URL. Ensuite, nous avons converti le contenu JSON en une base de données Python.</li>
#     <li><strong>Liste des nouveaux articles :</strong> Nous avons créé une liste vide appelée "new_articles" pour stocker les nouveaux articles que nous allons repérer.</li>
#     <li><strong>Parcourir les flux RSS :</strong> Nous avons parcouru à nouveau les flux RSS, en utilisant la bibliothèque feedparser pour lire les données de chaque flux.</li>
#     <li><strong>Parcourir les articles du flux RSS :</strong> Pour chaque flux RSS, nous avons parcouru les articles en utilisant une boucle.</li>
#     <li><strong>Extraction des informations de l'article :</strong> Nous avons extrait certaines informations clés de chaque article, telles que le titre, la date de publication et le lien.</li>
#     <li><strong>Vérification dans la base de données :</strong> Nous avons vérifié si l'article existe déjà dans la base de données en utilisant l'URL de l'article comme clé unique. Si l'article n'était pas déjà présent, nous l'avons ajouté à la liste des nouveaux articles.</li>
# </ol>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     À la fin de cette étape, la liste "new_articles" contient les nouveaux articles qui ne sont pas déjà présents dans la base de données. Ces articles peuvent ensuite être examinés plus en détail ou traités selon les besoins.
# </p>

# %%
# Désactivation de la vérification SSL (si nécessaire)
ssl._create_default_https_context = ssl._create_unverified_context

# URL du fichier JSON de la base de données existante
url_json = "https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/francetvinfo.json"
data_json = requests.get(url_json).json()

# Liste des nouveaux articles
new_articles = []

# Parcourir les flux RSS
for source_name, source_url in sources.items():
    data = fp.parse(source_url)
    
    # Parcourir les articles du flux RSS
    for item in data.entries:
        article = {
            "title": item.title,
            "published": item.published,
            "link": item.link,
            "description": item.description if "description" in item else "",
            "content": item.content[0].value if "content" in item else "",
        }
        
        # Vérifier si la liste enclosures n'est pas vide avant d'accéder à son premier élément
        if "enclosures" in item and len(item.enclosures) > 0 and item.enclosures[0].type == "image/jpeg":
            article["image_link"] = item.enclosures[0].url
        else:
            article["image_link"] = "Non spécifié"
        
        # Vérifier si l'article existe déjà dans la base de données en utilisant l'URL comme clé unique
        if article["link"] not in data_json:
            new_articles.append(article)

# Maintenant, new_articles contient la liste des nouveaux articles non présents dans la base de données.

# Afficher seulement quelques-uns des nouveaux articles
num_articles_to_display = 5  # Vous pouvez modifier le nombre d'articles à afficher
for i, new_article in enumerate(new_articles[:num_articles_to_display]):
    print(f"Article {i + 1}:")
    print("Titre:", new_article["title"])
    print("Date de publication:", new_article["published"])
    print("Lien:", new_article["link"])
    print("Description:", new_article["description"])
    print("Contenu:", new_article["content"])
    print("Lien de l'image:", new_article["image_link"])
    print("\n")

    # Compter le nombre de nouveaux articles
taille_nouveaux_articles = len(new_articles)
print(f"Taille des nouveaux articles : {taille_nouveaux_articles} articles")

df_new_articles = pd.DataFrame(new_articles)
df_new_articles.head(5)
# Out:
# Article 1:
# Titre: Animaux : dans les coulisses du Parc des oiseaux durant l'hiver
# Date de publication: Fri, 16 Feb 2024 16:09:05 +0100
# Lien: https://www.francetvinfo.fr/animaux/animaux-dans-les-coulisses-du-parc-des-oiseaux-durant-l-hiver_6369964.html#xtor=RSS-3-[france]
# Description: Dans l'Ain, le Parc des oiseaux de Villars-les-Dombes est fermé durant l'hiver. Sur place, les soigneurs prennent soin des 2 000 oiseaux du parc.
# Contenu:
# Lien de l'image: https://www.francetvinfo.fr/pictures/czhUf1ShPoVInx-kFcFp6EMr65k/432x243/2024/02/16/parc-oiseaux-65cf7a4bb644b503097085.jpg
#
#
# Article 2:
# Titre: Patrimoine : le château de Chenonceau, un bijou de la Renaissance
# Date de publication: Fri, 16 Feb 2024 16:04:48 +0100
# Lien: https://www.francetvinfo.fr/culture/patrimoine/patrimoine-le-chateau-de-chenonceau-un-bijou-de-la-renaissance_6369958.html#xtor=RSS-3-[france]
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: red; font-size: 18px;">Commentaire sur le repérage des nouveaux articles</h3>
#     <p>
#         Les résultats de l'analyse du flux RSS ont été enregistrés dans la table `new_articles`. Cette table contient les articles qui ne sont pas déjà présents dans la base de données existante, ce qui signifie qu'il s'agit des nouveaux articles depuis la dernière mise à jour de la base de données.
#     </p>
#     <p>
#         Cependant, il est important de noter que les contenus des articles ne sont pas disponibles dans cette sortie. Les informations disponibles incluent le titre de l'article, la date de publication, le lien, la description et le lien de l'image.
#     </p>
#     <p>
#         Cette approche permet de maintenir la base de données à jour en identifiant les nouveaux articles, mais pour accéder au contenu complet de ces articles, il serait nécessaire de suivre les liens fournis.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>Récupération des articles </h1></center>
# <center><h1>  QUESTION :  2 -Extraction des Informations à Partir de la Page Web</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour récupérer les informations essentielles à partir de la page web d'un article, nous avons utilisé la bibliothèque "newspaper" en Python. Voici comment nous avons procédé pour extraire ces informations :
# </p>
#
# <ol style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Définition de l'URL de l'article :</strong> Nous avons commencé par définir l'URL de l'article que nous souhaitions récupérer.</li>
#     <li><strong>Création de l'objet Article :</strong> Ensuite, nous avons créé un objet Article en utilisant la bibliothèque "newspaper" et en passant l'URL de l'article en tant que paramètre.</li>
#     <li><strong>Téléchargement de la Page Web :</strong> Nous avons téléchargé la page web de l'article en utilisant la méthode "download()" de l'objet Article.</li>
#     <li><strong>Analyse de la Page Web :</strong> Nous avons analysé la page web pour extraire le contenu en utilisant la méthode "parse()". Cette étape permet à la bibliothèque "newspaper" d'identifier automatiquement les zones du HTML contenant le titre de l'article, le texte de l'article, les auteurs et d'autres informations pertinentes.</li>
#     <li><strong>Accès aux Informations :</strong> Une fois l'analyse terminée, nous avons pu accéder aux différentes informations de l'article en utilisant les attributs de l'objet "article". Par exemple, nous avons extrait le titre, la date de publication, les auteurs, le contenu de l'article et l'URL de l'image associée.</li>
# </ol>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     L'utilisation de la bibliothèque "newspaper" s'est avérée extrêmement utile, car elle a simplifié le processus d'extraction des informations à partir de la page web. Elle a automatiquement identifié les zones pertinentes du HTML, ce qui nous a permis de gagner du temps et de réduire la complexité du code. Ces informations peuvent ensuite être utilisées pour diverses tâches, telles que l'analyse des articles ou la mise à jour d'une base de données.
#
# </p>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Le recours à la bibliothèque `newspaper` est précieux car elle simplifie considérablement le processus d'extraction du contenu de l'article à partir de la page web. Elle identifie automatiquement les zones du HTML contenant le titre, le texte de l'article, les auteurs et d'autres informations pertinentes. Cela permet d'économiser du temps et de réduire la complexité du code, car nous n'avons pas besoin d'analyser manuellement le HTML pour extraire ces informations.
# </p>

# %%
# L'URL de flux que nous voulons analyser
url = "https://www.francetvinfo.fr/france.rss"  

# Récupération et analyse du flux RSS
data = fp.parse(url)

# Sélectionner le premier article du flux RSS : que nous voulons analyser 
first_article_url = data.entries[0].link

# Créer un objet Article à partir de l'URL sélectionnée
article = np.Article(first_article_url)

# Télécharger le contenu de l'article
article.download()

# Utiliser la fonction dir() pour voir les attributs de l'objet "article"
print(f"Lien de l'arcticle que nous voulons analyser {first_article_url}")
print()
print(dir(article))
# Out:
# Lien de l'arcticle que nous voulons analyser https://www.francetvinfo.fr/animaux/animaux-dans-les-coulisses-du-parc-des-oiseaux-durant-l-hiver_6369964.html#xtor=RSS-3-[france]
#
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: red; font-size: 18px;">Explication des attributs de l'objet Article</h3>
#     <p>
#         Après avoir sélectionné et téléchargé le contenu d'un article via la librairie <code>newspaper</code>, plusieurs attributs peuvent être utilisés pour extraire des informations pertinentes :
#     </p>
#     <ul>
#         <li><strong>title</strong> : Contient le titre de l'article, ce qui est crucial pour identifier le sujet de l'article.</li>
#         <li><strong>text</strong> : Fournit le texte intégral de l'article, permettant une analyse détaillée du contenu.</li>
#         <li><strong>authors</strong> : Liste les auteurs de l'article, offrant une perspective sur les sources d'information.</li>
#         <li><strong>publish_date</strong> : La date de publication de l'article, utile pour contextualiser l'information dans le temps.</li>
#         <li><strong>summary</strong> : Un résumé de l'article, généré automatiquement, qui donne un aperçu rapide du contenu.</li>
#         <li><strong>keywords</strong> : Les mots-clés associés à l'article, aidant à comprendre les thèmes principaux.</li>
#         <li><strong>top_image</strong> : L'URL de l'image principale de l'article, enrichissant la présentation des données.</li>
#         <li><strong>movies</strong> : Contient les liens vers les vidéos incluses dans l'article, offrant un contenu multimédia complémentaire.</li>
#         <li><strong>meta_description</strong> : La description méta de la page, qui peut offrir un résumé succinct de l'article.</li>
#         <li><strong>meta_keywords</strong> : Les mots-clés méta de la page, pour une compréhension approfondie des sujets traités.</li>
#     </ul>
#     <p>
#         L'utilisation de ces attributs facilite grandement l'extraction et l'analyse automatiques du contenu des articles en ligne, permettant une collecte d'informations efficace et structurée.
#     </p>
# </div>

# %% [markdown]
# #  Que faudrait-il faire pour récupérer le texte de l’article ?  Exemple :

# %%
# Télécharger la page web
article.download()

# Analyser la page web pour extraire le contenu
article.parse()

# Maintenant, nous pouvons accéder aux différentes informations de l'article
titre_article = article.title  # Titre de l'article
date_publication = article.publish_date  # Date de publication
auteurs = article.authors  # Auteurs de l'article
contenu_article = article.text  # Contenu de l'article
image_url = article.top_image  # URL de l'image associée à l'article

# Afficher les informations
print(f"Lien de l'arcticle que nous voulons analyser {first_article_url}")
print()
print("Titre de l'article:", titre_article)
print("Date de publication:", date_publication)
print("Auteurs:", auteurs)
print("Contenu de l'article:", contenu_article)
print("URL de l'image:", image_url)
# Out:
# Lien de l'arcticle que nous voulons analyser https://www.francetvinfo.fr/animaux/animaux-dans-les-coulisses-du-parc-des-oiseaux-durant-l-hiver_6369964.html#xtor=RSS-3-[france]
#
# Titre de l'article: Animaux : dans les coulisses du Parc des oiseaux durant l'hiver
# Date de publication: 2024-02-16 16:09:05+01:00
# Auteurs: []
# Contenu de l'article: Dans l'Ain, le Parc des oiseaux de Villars-les-Dombes est fermé durant l'hiver. Sur place, les soigneurs prennent soin des 2 000 oiseaux du parc.
#
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: red; font-size: 18px;">Extraction d'informations d'un article dans le flux</h3>
#     <p>
#         Suite au téléchargement et à l'analyse de l'article, nous avons accès à plusieurs informations clés qui nous permettent de comprendre le contenu.
#         Ces informations extraites automatiquement grâce à la librairie <code>newspaper</code> permettent une analyse rapide et efficace du contenu en ligne, sans avoir à parcourir manuellement le code HTML de la page. Cela simplifie grandement le processus de collecte de données pour des analyses de contenu ou des revues d'actualités.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1> QUESTION 3 : Mise à Jour de la Base de Données d'Articles</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette section, nous expliquerons comment mettre à jour une base de données d'articles à partir de flux RSS en ajoutant le texte des articles et les liens vers les images illustrant les articles lorsque disponibles.
# </p>
#
# <h2 style="font-family: 'Arial', sans-serif; font-size: 16px;">Démarche du Code</h2>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Le code ci-dessous détaille les étapes pour accomplir cette tâche :
# </p>
#
# <ol style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Liste des Nouveaux Articles :</strong> Nous commençons par créer une liste vide pour stocker les nouveaux articles.</li>
#     <li><strong>Parcourir les Flux RSS :</strong> Nous parcourons les flux RSS spécifiés pour obtenir les informations des articles.</li>
#     <li><strong>Parcourir les Articles du Flux RSS :</strong> Pour chaque article dans le flux RSS, nous collectons des informations telles que le titre, la date de publication, le lien, la description, le contenu (initialisé à vide), et le lien de l'image (s'il y en a).</li>
#     <li><strong>Vérification de l'Existence :</strong> Nous vérifions si l'article existe déjà dans la base de données en utilisant l'URL comme clé unique.</li>
#     <li><strong>Mise à Jour des Informations de l'Article :</strong> Si l'article est nouveau, nous créons un objet Article à partir de l'URL de l'article, téléchargeons la page web, et analysons la page web pour extraire le contenu textuel complet de l'article, les auteurs, et l'URL de l'image.</li>
#     <li><strong>Ajout à la Liste des Nouveaux Articles :</strong> Nous ajoutons ensuite l'article à la liste des nouveaux articles.</li>
#     <li><strong>Mise à Jour de la Base de Données :</strong> Après avoir parcouru tous les articles, nous mettons à jour la base de données existante avec les nouveaux articles.</li>
# </ol>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Après l'exécution du code, la base de données sera mise à jour avec le contenu textuel complet des articles ainsi que les noms des auteurs lorsque disponibles. Elle sera prête à être utilisée pour un traitement ultérieur.
# </p>
# </body>
# </html>

# %%
def mettre_a_jour_base_de_donnees(flux_rss_a_lire, database):
    # Liste des nouveaux articles
    new_articles = []

    # Parcourir les flux RSS
    for source_url in flux_rss_a_lire:
        data = fp.parse(source_url)
        
        # Parcourir les articles du flux RSS
        for item in data.entries:
            article = {
                "title": item.title,
                "published": item.published,
                "link": item.link,
                "description": item.description if "description" in item else "",
                "content": "",  # Initialiser le contenu à vide
                "image_link": item.enclosures[0].url if "enclosures" in item and item.enclosures[0].type == "image/jpeg" else ""
            }
            
            # Vérifier si l'article existe déjà dans la base de données en utilisant l'URL comme clé unique
            if article["link"] not in database:
                # Créer un objet Article à partir de l'URL de l'article
                article_obj = np.Article(article["link"])
                article_obj.download()
                article_obj.parse()
                
                # Mettre à jour les informations de l'article
                article["content"] = article_obj.text
                article["authors"] = article_obj.authors
                article["image_url"] = article_obj.top_image
                
                # Ajouter l'article à la liste des nouveaux articles
                new_articles.append(article)

    # Mettre à jour la base de données existante avec les nouveaux articles
    for article in new_articles:
        database[article["link"]] = article

    # Retourner la base de données mise à jour
    return database

# Liste des flux RSS à parcourir
flux_rss_a_lire = list(sources.values())

# Charger la base de données existante depuis le lien francetvinfo.json
francetvinfo_url = "https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/francetvinfo.json"
response_database = requests.get(francetvinfo_url)
database = json.loads(response_database.text)

# Mettre à jour la base de données avec les nouveaux articles
database_mise_a_jour = mettre_a_jour_base_de_donnees(flux_rss_a_lire, database)

# Maintenant, database_mise_a_jour contient la base de données mise à jour avec le contenu et les auteurs des articles en plus des autres informations.

# %%
# Compter le nombre de nouveaux articles
taille_nouveaux_articles = len(database_mise_a_jour)
print(f"Taille des nouveaux articles : {taille_nouveaux_articles} articles")

# %% [markdown]
# # Extrait du contenu de la base de données mise à jour

# %%
# Afficher seulement quelques-uns des nouveaux articles
num_articles_to_display = 2  # Vous pouvez modifier le nombre d'articles à afficher
count = 0  # Compteur pour afficher le nombre d'articles spécifié

for article_link, article_info in database_mise_a_jour.items():
    print(f"Article {count + 1}:")
    print("Titre:", article_info["title"])
    
    # Vérifier si la clé "date" existe dans les informations de l'article
    if "date" in article_info:
        print("Date de publication:", article_info["date"])
    else:
        print("Date de publication non disponible")
        
    print("Lien:", article_link)
    
    # Vérifier si la clé "authors" existe dans les informations de l'article
    if "authors" in article_info:
        print("Auteurs:", ", ".join(article_info["authors"]))
    else:
        print("Auteurs non disponibles")
    
    # Vérifier si la clé "content" existe dans les informations de l'article
    if "content" in article_info:
        print("Contenu de l'article:")
        print(article_info["content"])
    else:
        print("Contenu de l'article non disponible")
    
    # Vérifier si la clé "image_link" existe dans les informations de l'article
    if "image_link" in article_info:
        print("URL de l'image:", article_info["image_link"])
    else:
        print("URL de l'image non disponible")
    
    print("\n")
    
    count += 1
    
    if count >= num_articles_to_display:
        break
# Out:
# Article 1:
# Titre: Violences contre les maires : dans l'Eure, des élus apprennent à se défendre
# Date de publication: 2020-01-19T16:31:16
# Lien: https://www.francetvinfo.fr/sante/prevention/eure-quand-les-elus-apprennent-a-se-defendre_3791635.html#xtor=RSS-3-[france]
# Auteurs non disponibles
# Contenu de l'article:
# Beaucoup de maires et de secrétaires de mairie ont rencontré au cours de leurs mandats des problèmes de violence, essentiellement verbale. C'est le cas de Claire. Un jour, un homme est entré dans son bureau et a frappé très fort sur son bureau pour l'intimider. "J'ai réagi à l'instinct, j'ai essayé de discuter, mais ça s'est envenimé. Heureusement qu'une dame est arrivée à la permanence et a menacé d'appeler la gendarmerie", raconte Claire Carrère-Godebout, maire (SE) de Graveron-Sémerville (Eure).
#
# Des professeurs de karaté et un psychologue
#
# ...

# %% [markdown]
# # Extrait du contenu de la base de données mise à jour (les news articles qui n'étaient pas présents dans la base de données existantes)

# %%
# Accéder à un article spécifique dans la base de données mise à jour
article_a_afficher = database_mise_a_jour['https://www.francetvinfo.fr/societe/securite-routiere/vrai-ou-faux-les-arbres-sont-ils-dangereux-pour-les-automobilistes_6366001.html#xtor=RSS-3-[france]']

# Afficher les informations de l'article
print("Titre de l'article:", article_a_afficher["title"])
print("Date de publication:", article_a_afficher["published"])
print("Lien:", article_a_afficher["link"])
print("Description:", article_a_afficher["description"])
print("Contenu de l'article:", article_a_afficher["content"])
print("Image de l'article:", article_a_afficher["image_link"])
# Out:
# Titre de l'article: VRAI OU FAUX. Les arbres sont-ils dangereux pour les automobilistes ?
# Date de publication: Wed, 14 Feb 2024 20:49:19 +0100
# Lien: https://www.francetvinfo.fr/societe/securite-routiere/vrai-ou-faux-les-arbres-sont-ils-dangereux-pour-les-automobilistes_6366001.html#xtor=RSS-3-[france]
# Description: Faut-il choisir entre sécurité routière et préservation de la nature ? Le Conseil départemental de Haute-Marne a choisi d'abattre jusqu’à 4 000 arbres sur le bord des routes. Sont-ils une menace pour les automobilistes ? L’équipe de Vrai ou Faux a enquêté.
# Contenu de l'article: Faut-il choisir entre sécurité routière et préservation de la nature ? Le Conseil départemental de Haute-Marne a choisi d'abattre jusqu’à 4 000 arbres sur le bord des routes. Sont-ils une menace pour les automobilistes ? L’équipe de Vrai ou Faux a enquêté.
#
# ...

# %%
df = pd.DataFrame(database_mise_a_jour).T
df
# Out:
#                                                                                                 title  \
# https://www.francetvinfo.fr/sante/prevention/eu...  Violences contre les maires : dans l'Eure, des...
# https://www.francetvinfo.fr/france/video-sur-le...  VIDEO. Sur le dos d'un aigle pêcheur au-dessus...
# https://www.francetvinfo.fr/societe/video-massi...  VIDEO. Dans le massif du Mont-Blanc, la hausse...
# https://www.francetvinfo.fr/replay-magazine/fra...  "13h15 le dimanche". Le Mont-Blanc, un mythe é...
# https://www.francetvinfo.fr/societe/loi-de-bioe...  Loi de bioéthique : les opposants à la PMA man...
# ...                                                                                               ...
# https://www.francetvinfo.fr/economie/entreprise...  Le groupe Disney dépasse les attentes avec 2,1...
# https://www.francetvinfo.fr/economie/energie/to...  TotalEnergies : un bénéfice record de 19,8 mil...
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <h3 style="color: red; font-size: 18px;">Mise à Jour de la Base de Données avec le Contenu des Articles</h3>
#     <p>
#         Suite à la mise à jour de la base de données, nous sommes désormais en mesure d'accéder au contenu complet de chaque article repéré comme nouveau. Cette amélioration significative nous permet d'explorer plus en détail les informations contenues dans ces articles sans avoir à suivre manuellement les liens.
#     </p>
#     <p>
#         Chaque article nouvellement repéré comprend maintenant les informations suivantes : le titre de l'article, la date de publication, le lien vers l'article, la description, le contenu complet de l'article et l'URL de l'image associée. Ces données supplémentaires facilitent grandement l'analyse et la compréhension des sujets abordés dans les articles.
#     </p>
#     <p>
#         Cette mise à jour renforce la qualité de notre base de données en fournissant un accès complet aux informations, ce qui est essentiel pour une utilisation future dans des analyses, des recherches et d'autres traitements de données.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1> QUESTION 4 : Stockage d'Images Locales dans la Base de Données</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour stocker des images localement dans notre base de données, nous pouvons suivre une démarche générale comme suit :
# </p>
#
# <ol style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Téléchargement des Images :</strong> Lorsque nous récupérons des articles à partir de flux RSS, nous identifions les liens des images associées aux articles.</li>
#     <li><strong>Téléchargement Local :</strong> Une fois que nous avons les liens des images, nous pouvons télécharger ces images depuis leur source d'origine en utilisant des bibliothèques Python telles que "requests".</li>
#     <li><strong>Stockage dans la Base de Données :</strong> Après avoir téléchargé les images, nous pouvons les stocker localement dans notre base de données. Cela peut être fait en enregistrant le contenu binaire des images dans des colonnes de la base de données spécialement conçues pour stocker des fichiers binaires.</li>
#     <li><strong>Utilisation d'une Clé Unique :</strong> Pour faciliter la gestion des images, il est recommandé d'utiliser une clé unique pour chaque image, généralement basée sur un identifiant unique de l'article associé à l'image. Cela permet de référencer facilement chaque image dans la base de données.</li>
#     <li><strong>Associations avec les Articles :</strong> Chaque image stockée localement dans la base de données peut être associée à l'article correspondant en utilisant l'identifiant unique de l'article comme clé étrangère. Ainsi, nous pouvons retrouver rapidement les images liées à un article spécifique.</li>
#     <li><strong>Actualisation :</strong> Si une image venait à disparaître du site d'origine, nous conserverions toujours une copie locale dans notre base de données pour référence ultérieure.</li>
# </ol>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En suivant cette démarche, nous serions en mesure de stocker des copies locales d'images dans notre base de données, ce qui garantirait que nous disposons toujours d'une référence à ces images, même si elles venaient à disparaître du site web d'origine.
# </p>
# </body>
# </html>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION  5 : Collecte d'Informations Complémentaires à Partir d'Autres Sources</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour collecter des informations complémentaires sur les articles, nous pouvons explorer d'autres sources d'informations, telles que les réseaux sociaux, les flux RSS d'autres sites, et les API de médias sociaux. Voici quelques idées sur ce que nous pourrions collecter à partir de ces sources et des bibliothèques qui pourraient nous aider :
# </p>
#
# <h2 style="font-family: 'Arial', sans-serif; font-size: 16px;">Réseaux Sociaux</h2>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En analysant les réseaux sociaux, nous pourrions collecter des informations telles que les commentaires des utilisateurs, les partages, les likes, et les discussions liées à un article. Les bibliothèques Python telles que "Tweepy" pour Twitter, "praw" pour Reddit, et "python-instagram" pour Instagram pourraient nous aider à accéder à ces données.
# </p>
#
# <h2 style="font-family: 'Arial', sans-serif; font-size: 16px;">Flux RSS d'Autres Sites</h2>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En utilisant des flux RSS provenant d'autres sites d'actualités, nous pourrions collecter des articles connexes ou similaires à ceux de notre base de données. Cela nous permettrait de fournir des articles connexes aux utilisateurs. Les bibliothèques Python telles que "feedparser" pourraient être utilisées pour parcourir ces flux RSS.
# </p>
#
# <h2 style="font-family: 'Arial', sans-serif; font-size: 16px;">API de Médias Sociaux</h2>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les API de médias sociaux, comme l'API de Twitter, permettent d'accéder à des données en temps réel à partir de ces plateformes. Nous pourrions collecter des tweets liés aux articles, des statistiques sur l'engagement des utilisateurs, et des informations sur les tendances liées aux sujets des articles. Les bibliothèques Python, telles que "tweepy", peuvent être utilisées pour interagir avec ces API.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En explorant ces sources et en utilisant les bibliothèques appropriées, nous pourrions enrichir notre base de données avec des informations complémentaires, telles que les réactions des utilisateurs sur les réseaux sociaux, des articles connexes, et des données en temps réel provenant des médias sociaux.
# </p>
# </body>
# </html>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1> QUESTION 6 : Extraction d’information à partir de la base de données</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <h2>Objectif</h2>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette section, nous expliquerons notre démarche pour extraire des informations à partir de la base de données constituée en extrayant les flux RSS de francetvinfo.fr francetvinfo.json. L'objectif principal est de rechercher des entités nommées telles que les personnes, les organisations et les lieux dans les articles.
# </p>
#
# <h2>Extraction des Entités Nommées</h2>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     La première étape de notre démarche consiste à appliquer la détection des entités nommées à l'ensemble des documents de la base de données. Pour ce faire, nous avons utilisé spaCy avec la chaîne de traitement "fr_core_news_md" pour le français. Les entités nommées que nous recherchons sont des entités de type personne, organisation et lieu.
# </p>
#
# <h2>Limite de Traitement</h2>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En raison du temps de traitement élevé sur l'ensemble du contenu, nous avons décidé de limiter le traitement aux 2000 premiers articles de la base de données.
# </p>
#
# <h2>Résultats</h2>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les résultats de notre extraction d'entités nommées sont imprimés dans le code Python, mais nous avons limité l'affichage à seulement 5 résultats pour des raisons de concision. Vous pouvez consulter le code Python pour plus de détails.
# </p>
# </body>
# </html>

# %%
# Chargez le modèle spaCy en français
nlp = spacy.load("fr_core_news_md")

# Limite le traitement aux 2000 premiers articles
num_articles_to_process = 2000
articles_processed = 0

# Parcourez chaque article dans la base de données
for article_url, article_info in database_mise_a_jour.items():
    # Vérifiez si le nombre maximum d'articles à traiter a été atteint
    if articles_processed >= num_articles_to_process:
        break  # Sortez de la boucle une fois les 2000 premiers articles traités
    
    # Obtenez le contenu de l'article
    article_content = article_info['content']
    
    # Traitez le contenu avec spaCy
    doc = nlp(article_content)
    
    # Parcourez les entités nommées détectées dans le contenu de l'article
    for ent in doc.ents:
        print("Texte de l'entité:", ent.text)
        print("Début:", ent.start)
        print("Fin:", ent.end)
        print("Type d'entité:", ent.label_)
        print("---")
    
    articles_processed += 1

    # Limite l'affichage à seulement 5 résultats
    if articles_processed >= 1:
        break
# Out:
# Texte de l'entité: Claire
# Début: 28
# Fin: 29
# Type d'entité: PER
# ---
# Texte de l'entité: Claire Carrère-Godebout
# Début: 91
# Fin: 95
# Type d'entité: PER
# ---
# Texte de l'entité: SE
# Début: 98
# Fin: 99
# Type d'entité: LOC
# ---
# Texte de l'entité: Graveron-Sémerville
# Début: 101
# Fin: 104
# Type d'entité: LOC
# ---
# Texte de l'entité: Eure
# Début: 105
# Fin: 106
# Type d'entité: LOC
# ---
# Texte de l'entité: Association des maires ruraux de l'Eure
# Début: 137
# Fin: 144
# Type d'entité: ORG
# ---
# Texte de l'entité: Christophe Micaux
# Début: 200
# Fin: 202
# Type d'entité: PER
# ---

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <!-- Titre de la section -->
#     <h3 style="color: red; font-size: 18px;">Interprétation des Entités Nommées Extraites</h3>
#     <!-- Introduction -->
#     <p>
#         Les résultats ci-dessous sont le fruit de notre processus d'extraction d'entités nommées à partir du contenu des articles :
#     </p>
#     <!-- Résultats -->
#     <ul>
#         <li>
#             <strong>Texte de l'entité:</strong> Claire<br>
#             <strong>Début:</strong> 28<br>
#             <strong>Fin:</strong> 29<br>
#             <strong>Type d'entité:</strong> PER<br>
#             <em>Interprétation:</em> Nous avons identifié une entité nommée "Claire" de type "PER" (personne) dans le texte. Cela peut correspondre au nom d'une personne mentionnée dans l'article.
#         </li>
#         <li>
#             <strong>Texte de l'entité:</strong> Claire Carrère-Godebout<br>
#             <strong>Début:</strong> 91<br>
#             <strong>Fin:</strong> 95<br>
#             <strong>Type d'entité:</strong> PER<br>
#             <em>Interprétation:</em> Une autre entité nommée "Claire Carrère-Godebout" de type "PER" a été identifiée, ce qui peut également représenter le nom complet d'une personne dans le texte.
#         </li>
#         <!-- Ajoutez des éléments similaires pour chaque entité détectée -->
#     </ul>
#     <!-- Conclusion -->
#     <p>
#         Ces entités nommées extraites, telles que les noms de personnes, d'organisations et de lieux, nous fournissent des informations importantes sur les sujets et les acteurs mentionnés dans les articles. Cela facilite la catégorisation et l'analyse du contenu de notre base de données.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 7 : Étiquettes IOB et Détection des Entités Nommées</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les étiquettes IOB (Inside, Outside, Beginning) sont couramment utilisées dans la détection des entités nommées pour annoter des éléments spécifiques dans le texte. Elles permettent de marquer chaque mot ou token d'une phrase en fonction de son rôle par rapport à une entité nommée.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     - <strong>Inside (I):</strong> L'étiquette "I" est utilisée pour marquer les mots qui se trouvent à l'intérieur d'une entité nommée déjà identifiée. Par exemple, si "Paris" est une entité nommée de type "LOC" (lieu), alors les mots suivants comme "en" et "France" recevront l'étiquette "I-LOC" pour indiquer qu'ils font partie de l'entité nommée "Paris".
# </p>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     - <strong>Outside (O):</strong> L'étiquette "O" est attribuée aux mots qui ne font pas partie d'une entité nommée. Cela signifie qu'ils ne sont pas pertinents pour l'entité en cours d'identification.
# </p>
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     - <strong>Beginning (B):</strong> L'étiquette "B" est utilisée pour marquer le premier mot d'une entité nommée. Par exemple, dans "Jean Dupont est maire de Paris", "Jean" recevrait l'étiquette "B-PER" pour indiquer qu'il est le début d'une entité nommée de type "PER" (personne).
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     La détection des entités nommées repose généralement sur des modèles d'apprentissage automatique supervisé. Voici une brève description de la technique :
# </p>
#
# <ol style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Description de la tâche :</strong> La tâche de détection des entités nommées consiste à identifier et à classer les entités nommées (personnes, lieux, organisations, etc.) dans un texte non structuré.</li>
#     <li><strong>Modèle :</strong> Les modèles d'apprentissage automatique, tels que les réseaux de neurones, les CRF (Conditional Random Fields) ou les modèles basés sur les transformers, sont couramment utilisés pour cette tâche.</li>
#     <li><strong>Entraînement :</strong> Le modèle est entraîné sur un grand corpus de textes annotés, où chaque entité nommée est marquée avec les étiquettes IOB correspondantes.</li>
#     <li><strong>Prédiction :</strong> Une fois entraîné, le modèle est capable de prédire les entités nommées dans de nouveaux textes en attribuant les étiquettes IOB appropriées aux tokens.</li>
# </ol>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En utilisant cette technique, il est possible d'automatiser la détection des entités nommées dans de vastes ensembles de données textuelles, ce qui est essentiel pour des applications telles que la constitution de bases de connaissances, la veille économique et le fact-checking dans le domaine de la presse.
# </p>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 8 :Extraction d'Entités Nommées à partir de la Base de Données</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette partie de notre projet, nous avons mis en place un processus d'extraction d'entités nommées à partir de la base de données constituée en ayant scrappé les flux RSS du site francetvinfo.fr. Cette étape est essentielle pour extraire des informations spécifiques à partir des articles que nous avons collectés.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Notre objectif principal était de rechercher des informations sur des entités nommées telles que les personnes, les organisations et les lieux, ainsi que de capturer les relations qui peuvent exister entre ces entités. Ce processus d'extraction d'informations est crucial dans divers domaines tels que la constitution de bases de connaissances, la veille économique et le fact-checking dans le monde de la presse.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour réaliser cette tâche, nous avons utilisé spaCy, une bibliothèque de traitement du langage naturel en Python. Nous avons chargé le modèle spaCy en français (fr_core_news_md) pour analyser les textes en français.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Le processus consiste à parcourir l'ensemble des articles de la base de données et à appliquer la détection d'entités nommées sur chacun d'eux. spaCy identifie les entités telles que les noms de personnes, les noms d'organisations et les noms de lieux, puis extrait leurs informations, y compris le texte de l'entité, le début et la fin de l'entité dans le texte, ainsi que le type d'entité.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les résultats de cette extraction sont ensuite stockés dans une structure de données appropriée, permettant de référencer facilement les entités extraites pour chaque article. Nous avons optimisé le temps de traitement en utilisant la commande "pipe" de spaCy, veillant ainsi à ne traiter chaque article qu'une seule fois.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En somme, cette étape d'extraction d'entités nommées enrichit notre base de données en fournissant des informations clés sur les entités présentes dans les articles, ce qui sera précieux pour des analyses futures, des recherches et d'autres traitements de données.
# </p>
# </body>
# </html>

# %%
# Charger la base de données existante depuis le lien francetvinfo.json
francetvinfo_url = "https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/francetvinfo.json"
response_database = requests.get(francetvinfo_url)
database = json.loads(response_database.text)

# Charger le modèle spaCy en français
nlp = spacy.load("fr_core_news_md")

# Créer une fonction pour extraire les entités nommées et leurs informations
def extract_entities(article_content):
    # Traiter le contenu de l'article avec spaCy en utilisant la commande pipe
    doc = nlp(article_content)
    
    # Initialiser une liste pour stocker les informations des entités
    entities_info = []
    
    # Parcourir les entités nommées détectées dans le contenu de l'article
    for ent in doc.ents:
        entity_info = {
            "text": ent.text,
            "start": ent.start,
            "end": ent.end,
            "type": ent.label_
        }
        entities_info.append(entity_info)
    
    return entities_info

# Créer un dictionnaire pour stocker les entités et leurs informations pour chaque article
articles_entities = {}

# Parcourir chaque article dans la base de données
for article_url, article_info in database.items():
    # Vérifier si l'article a déjà été traité
    if article_url in articles_entities:
        continue
    
    # Obtenir le contenu de l'article
    article_content = article_info['content']
    
    # Extraire les entités et leurs informations
    entities_info = extract_entities(article_content)
    
    # Stocker les informations des entités dans le dictionnaire
    articles_entities[article_url] = entities_info

# Afficher les entités extraites pour le premier article (pour illustrer)
print("Entités pour le premier article:")
print(articles_entities[list(database.keys())[0]])
# Out:
# Entités pour le premier article:
# [{'text': 'Claire', 'start': 28, 'end': 29, 'type': 'PER'}, {'text': 'Claire Carrère-Godebout', 'start': 91, 'end': 95, 'type': 'PER'}, {'text': 'SE', 'start': 98, 'end': 99, 'type': 'LOC'}, {'text': 'Graveron-Sémerville', 'start': 101, 'end': 104, 'type': 'LOC'}, {'text': 'Eure', 'start': 105, 'end': 106, 'type': 'LOC'}, {'text': "Association des maires ruraux de l'Eure", 'start': 137, 'end': 144, 'type': 'ORG'}, {'text': 'Christophe Micaux', 'start': 200, 'end': 202, 'type': 'PER'}]

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <!-- Titre de la section -->
#     <h3 style="color: red; font-size: 18px;">Commentaire sur les Entités Nommées Extraiets</h3>
#     <!-- Introduction -->
#     <p>
#         Les résultats d'extraction d'entités nommées à partir du contenu des articles sont présentés ci-dessous :
#     </p>
#     <!-- Commentaire général -->
#     <p>
#         Les entités nommées extraites comprennent des noms de personnes (PER), d'organisations (ORG) et de lieux (LOC) qui ont été identifiés dans le texte des articles. Ces entités fournissent des informations clés sur les sujets abordés, les personnes mentionnées et les lieux géographiques évoqués dans les articles. L'extraction de telles entités facilite la catégorisation, l'analyse et l'organisation du contenu de notre base de données, ce qui est essentiel pour des applications telles que la veille économique, la création de fiches de renseignement sur les entités et le fact-checking dans le domaine de la presse.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 9 : Analyse des Entités Nommées</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette section, nous abordons l'analyse des entités nommées détectées à l'étape précédente de notre projet. Notre objectif est d'identifier les 20 entités les plus fréquentes pour chaque type d'entité (personnes, organisations et lieux) au sein de la collection de documents que nous avons constituée.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour ce faire, nous avons suivi un processus en plusieurs étapes. Tout d'abord, nous avons extrait les entités nommées de chaque article en utilisant spaCy, une bibliothèque de traitement du langage naturel en Python. Ces entités comprennent les noms de personnes, les noms d'organisations et les noms de lieux.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Ensuite, nous avons regroupé ces entités par type (personnes, organisations et lieux) et compté leur fréquence d'apparition dans l'ensemble de la collection de documents.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les résultats obtenus sont présentés ci-dessous, avec les 20 entités les plus fréquentes pour chaque type d'entité. Ces informations nous permettront de mieux comprendre quelles sont les entités les plus mentionnées dans nos articles et d'obtenir un aperçu des sujets ou des acteurs qui reviennent le plus fréquemment.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Nous utiliserons ces données pour des analyses ultérieures et pour approfondir notre compréhension du contenu de notre base de données.
# </p>
# </body>
# </html>

# %%
# Charger la base de données existante depuis le lien francetvinfo.json
francetvinfo_url = "https://people.irisa.fr/Guillaume.Gravier/teaching/ENSAI/data/francetvinfo.json"
response_database = requests.get(francetvinfo_url)
database = json.loads(response_database.text)

# Charger le modèle spaCy en français
nlp = spacy.load("fr_core_news_md")

# Créer une fonction pour extraire les entités nommées et leurs informations
def extract_entities(article_content):
    # Traiter le contenu de l'article avec spaCy en utilisant la commande pipe
    doc = nlp(article_content)
    
    # Initialiser une liste pour stocker les informations des entités
    entities_info = []
    
    # Parcourir les entités nommées détectées dans le contenu de l'article
    for ent in doc.ents:
        entity_info = {
            "text": ent.text,
            "start": ent.start,
            "end": ent.end,
            "type": ent.label_
        }
        entities_info.append(entity_info)
    
    return entities_info

# Créer un dictionnaire pour stocker les entités et leurs informations pour chaque article
articles_entities = {}

# Parcourir chaque article dans la base de données
for article_url, article_info in database.items():
    # Vérifier si l'article a déjà été traité
    if article_url in articles_entities:
        continue
    
    # Obtenir le contenu de l'article
    article_content = article_info['content']
    
    # Extraire les entités et leurs informations
    entities_info = extract_entities(article_content)
    
    # Stocker les informations des entités dans le dictionnaire
    articles_entities[article_url] = entities_info

# Créez des listes pour stocker les textes des entités par type
people_entities = []
organization_entities = []
location_entities = []

# Parcourir les entités extraites et les trier par type
for article_entities in articles_entities.values():
    for entity_info in article_entities:
        entity_text = entity_info["text"]
        entity_type = entity_info["type"]
        
        if entity_type == "PER":
            people_entities.append(entity_text)
        elif entity_type == "ORG":
            organization_entities.append(entity_text)
        elif entity_type == "LOC":
            location_entities.append(entity_text)

# Comptez la fréquence des entités pour chaque type
people_entity_counts = Counter(people_entities)
organization_entity_counts = Counter(organization_entities)
location_entity_counts = Counter(location_entities)

# Sélectionnez les 20 entités les plus fréquentes pour chaque type
top_20_people_entities = people_entity_counts.most_common(20)
top_20_organization_entities = organization_entity_counts.most_common(20)
top_20_location_entities = location_entity_counts.most_common(20)

# Affichez les résultats
print("Top 20 des entités nommées de type PERSONNES les plus fréquentes :")
print(top_20_people_entities)

print("Top 20 des entités nommées de type ORGANISATIONS les plus fréquentes :")
print(top_20_organization_entities)

print("Top 20 des entités nommées de type LIEUX les plus fréquentes :")
print(top_20_location_entities)
# Out:
# Top 20 des entités nommées de type PERSONNES les plus fréquentes :
# [('Emmanuel Macron', 251), ('Covid-19', 182), ('Angela Merkel', 118), ('Bruno Le Maire', 115), ('Boris Johnson', 68), ('Muriel Pénicaud', 59), ('Laurent Desbonnets', 50), ('président de la République', 47), ('Thierry Breton', 44), ('Ursula von der Leyen', 41), ('Edouard Philippe', 40), ('Donald Trump', 37), ('Birkenau', 37), ('Olivier Véran', 33), ('Recep Tayyip Erdogan', 32), ('Kyriakos Mitsotakis', 28), ('Covid', 27), ('George Floyd', 27), ('Valéry Lerouge', 26), ('Michel Barnier', 25)]
# Top 20 des entités nommées de type ORGANISATIONS les plus fréquentes :
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <!-- Titre de la section -->
#     <h3 style="color: red; font-size: 18px;">Interprétation des Entités Nommées Extraites</h3>
#     <!-- Introduction -->
#     <p>
#         Les résultats d'extraction d'entités nommées à partir du contenu des articles sont présentés ci-dessous :
#     </p>
#     <!-- Commentaire général -->
#     <p>
#         Les entités nommées extraites comprennent des noms de personnes (PER), d'organisations (ORG) et de lieux (LOC) qui ont été identifiés dans le texte des articles. Ces entités fournissent des informations clés sur les sujets abordés, les personnes mentionnées et les lieux géographiques évoqués dans les articles. L'extraction de telles entités facilite la catégorisation, l'analyse et l'organisation du contenu de notre base de données, ce qui est essentiel pour des applications telles que la veille économique, la création de fiches de renseignement sur les entités et le fact-checking dans le domaine de la presse.
#     </p>
#     <!-- Commentaire sur les entités de type PERSONNES -->
#     <h4>Entités de type PERSONNES les plus fréquentes :</h4>
#     <ul>
#         <li><strong>1. Emmanuel Macron (251 occurrences)</strong>: Le président français Emmanuel Macron est l'entité nommée la plus fréquemment mentionnée, ce qui est compréhensible étant donné son rôle politique.</li>
#         <li><strong>2. Covid-19 (182 occurrences)</strong>: La pandémie de Covid-19 est également un sujet majeur, avec de nombreuses mentions dans les articles.</li>
#         <li><strong>3. Angela Merkel (118 occurrences)</strong>: La chancelière allemande Angela Merkel est une figure politique importante en Europe.</li>
#         <!-- Ajoutez des commentaires similaires pour les autres entités -->
#     </ul>
#     <!-- Commentaire sur les entités de type ORGANISATIONS -->
#     <h4>Entités de type ORGANISATIONS les plus fréquentes :</h4>
#     <ul>
#         <li><strong>1. JT (2081 occurrences)</strong>: Le journal télévisé (JT) est l'organisation la plus fréquemment mentionnée, indiquant peut-être que les articles font souvent référence aux reportages télévisés.</li>
#         <li><strong>2. franceinfo (477 occurrences)</strong>: franceinfo est une source d'information majeure en France, ce qui explique sa fréquence.</li>
#         <li><strong>3. Covid-19 (454 occurrences)</strong>: La pandémie continue d'être un sujet central dans de nombreux articles.</li>
#         <!-- Ajoutez des commentaires similaires pour les autres entités -->
#     </ul>
#     <!-- Commentaire sur les entités de type LIEUX -->
#     <h4>Entités de type LIEUX les plus fréquentes :</h4>
#     <ul>
#         <li><strong>1. France (797 occurrences)</strong>: La France est le lieu le plus fréquemment mentionné, ce qui est attendu étant donné le contexte français des articles.</li>
#         <li><strong>2. Allemagne (565 occurrences)</strong>: L'Allemagne est également un pays européen souvent évoqué.</li>
#         <li><strong>3. Paris (374 occurrences)</strong>: La capitale française est un lieu fréquent dans les articles.</li>
#         <!-- Ajoutez des commentaires similaires pour les autres entités -->
#     </ul>
#     <!-- Remarques -->
#     <p>
#         Il est intéressant de noter que les personnes les plus fréquemment mentionnées incluent des dirigeants politiques tels qu'Emmanuel Macron et Angela Merkel, ainsi que des références à la pandémie de Covid-19. Les organisations les plus fréquentes sont principalement liées aux médias, aux informations et à la pandémie. En ce qui concerne les lieux, la France, l'Allemagne et Paris sont les plus fréquemment évoqués, ce qui reflète probablement le contexte des articles.
#     </p>
#     <!-- Incohérences -->
#     <p>
#         Aucune incohérence majeure n'a été relevée dans les entités nommées extraites. Cependant, il est important de noter que certaines entités peuvent apparaître sous différentes formes (par exemple, "Covid-19" et "Covid") et pourraient être normalisées pour une analyse plus précise.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 10 : Détection des Co-Occurrences d'Entités Nommées</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette section, nous abordons la détection des co-occurrences d'entités nommées au sein des documents de notre collection. Le but de cette étape est de déterminer combien de fois deux entités nommées données apparaissent ensemble dans un même document, ce qui peut indiquer une relation ou un lien potentiel entre ces entités.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour atteindre cet objectif, nous avons développé une fonction personnalisée en Python. Cette fonction prend en entrée une paire d'entités nommées ainsi que leurs types correspondants (par exemple, une personne et une organisation) et calcule le nombre de co-occurrences de ces deux entités au sein d'un même document de notre collection.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     La détection des co-occurrences est une technique couramment utilisée pour identifier des relations potentielles entre des entités. Une fréquence de co-occurrence élevée suggère généralement un lien significatif entre les entités, ce qui peut être utile pour des analyses ultérieures telles que l'identification de partenariats, de citations ou de thèmes récurrents.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les résultats de cette détection des co-occurrences peuvent fournir des informations précieuses pour notre projet, notamment pour la création de graphes de relations entre entités et l'exploration de la manière dont les entités interagissent au sein de nos documents.
# </p>
# </body>
# </html>

# %%
# Fonction pour calculer le nombre de co-occurrences de deux entités dans un document
def count_entity_cooccurrences(entity1, entity2, entity_type1, entity_type2, articles_entities):
    cooccurrence_count = 0
    """
    Cette fonction compte le nombre de co-occurrences de deux entités d'un même type dans la collection de documents.
    
    Args:
        entity1 (str): Le texte de la première entité.
        entity2 (str): Le texte de la deuxième entité.
        type1 (str): Le type de la première entité (PER, ORG ou LOC).
        type2 (str): Le type de la deuxième entité (PER, ORG ou LOC).
        articles_entities (dict): Un dictionnaire contenant les entités extraites pour chaque document.

    Returns:
        int: Le nombre de co-occurrences de ces deux entités dans la collection.
    """
    # Parcourir les articles et leurs entités
    for entities_info in articles_entities.values():
        # Vérifier si les deux types d'entités sont présents dans l'article
        if any(entity_info["type"] == entity_type1 for entity_info in entities_info) and \
           any(entity_info["type"] == entity_type2 for entity_info in entities_info):
            # Vérifier si les deux entités co-occurrent dans le même article
            entity1_present = any(entity_info["text"] == entity1 for entity_info in entities_info)
            entity2_present = any(entity_info["text"] == entity2 for entity_info in entities_info)
            if entity1_present and entity2_present:
                cooccurrence_count += 1
    
    return cooccurrence_count

# Exemple d'utilisation de la fonction
entity1 = "Emmanuel Macron"
entity2 = "Covid-19"
entity_type1 = "PER"
entity_type2 = "LOC"

# Appel de la fonction pour compter les co-occurrences
cooccurrence_count = count_entity_cooccurrences(entity1, entity2, entity_type1, entity_type2, articles_entities)

# Affichage du résultat
print(f"Le nombre de co-occurrences de '{entity1}' ({entity_type1}) et '{entity2}' ({entity_type2}) est de {cooccurrence_count}")
# Out:
# Le nombre de co-occurrences de 'Emmanuel Macron' (PER) et 'Covid-19' (LOC) est de 44

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 11 : Analyse des Co-Occurrences d'Entités Nommées de Types Différents</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette section, nous explorons les co-occurrences d'entités nommées de types différents au sein de notre collection de documents. L'objectif est de rechercher les paires d'entités nommées de types différents qui apparaissent le plus souvent ensemble dans un même document, ce qui peut indiquer des relations ou des liens significatifs entre ces entités de nature différente.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour accomplir cette tâche, nous utilisons la fonction personnalisée que nous avons développée précédemment. Cette fonction prend en entrée une paire d'entités nommées avec leurs types respectifs, par exemple, une personne et une organisation, et calcule le nombre de co-occurrences de ces entités dans nos documents.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     L'analyse des co-occurrences entre entités de types différents peut révéler des relations intéressantes et des informations pertinentes pour notre projet. Une fréquence élevée de co-occurrence suggère des connexions significatives entre des entités de natures différentes, ce qui peut être utile pour comprendre comment différentes entités interagissent dans nos articles.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les résultats obtenus seront commentés afin de mettre en évidence les paires d'entités qui se co-occurrent le plus fréquemment, offrant ainsi un aperçu des relations et des sujets clés dans notre collection de documents.
# </p>
# </body>
# </html>

# %%
# Créer une fonction pour rechercher les paires d'entités de types différents qui apparaissent le plus souvent ensemble
def find_most_frequent_entity_pairs(articles_entities):
    entity_pairs_count = {}  # Dictionnaire pour stocker les comptes des paires d'entités
    
    # Parcourir les articles et leurs entités
    for entities_info in articles_entities.values():
        # Créer des ensembles distincts d'entités pour chaque type
        people_entities = set()
        organization_entities = set()
        location_entities = set()
        
        for entity_info in entities_info:
            entity_text = entity_info["text"]
            entity_type = entity_info["type"]
            
            # Ajouter l'entité à l'ensemble correspondant
            if entity_type == "PER":
                people_entities.add(entity_text)
            elif entity_type == "ORG":
                organization_entities.add(entity_text)
            elif entity_type == "LOC":
                location_entities.add(entity_text)
        
        # Générer des paires de types différents et les compter
        for entity1 in people_entities:
            for entity2 in organization_entities.union(location_entities):
                entity_pair = (entity1, entity2)
                entity_pairs_count[entity_pair] = entity_pairs_count.get(entity_pair, 0) + 1
    
    # Trier les paires par fréquence décroissante
    sorted_entity_pairs = sorted(entity_pairs_count.items(), key=lambda x: x[1], reverse=True)
    
    return sorted_entity_pairs

# Appel de la fonction pour trouver les paires d'entités
frequent_entity_pairs = find_most_frequent_entity_pairs(articles_entities)

# Affichage des 10 paires d'entités les plus fréquentes
top_10_entity_pairs = frequent_entity_pairs[:10]
for pair, count in top_10_entity_pairs:
    entity1, entity2 = pair
    print(f"Paire d'entités : '{entity1}' et '{entity2}' - Fréquence : {count}")
# Out:
# Paire d'entités : 'Covid-19' et 'JT' - Fréquence : 64
# Paire d'entités : 'Angela Merkel' et 'Allemagne' - Fréquence : 62
# Paire d'entités : 'Covid-19' et 'France' - Fréquence : 55
# Paire d'entités : 'Covid-19' et 'Covid-19' - Fréquence : 53
# Paire d'entités : 'Emmanuel Macron' et 'franceinfo' - Fréquence : 48
# Paire d'entités : 'Emmanuel Macron' et 'France' - Fréquence : 45
# Paire d'entités : 'Emmanuel Macron' et 'la France' - Fréquence : 41
# Paire d'entités : 'Laurent Desbonnets' et 'JT' - Fréquence : 41
# Paire d'entités : 'Laurent Desbonnets' et 'Berlin' - Fréquence : 41
# Paire d'entités : 'Emmanuel Macron' et 'JT' - Fréquence : 40

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <!-- Titre de la section -->
#     <h3 style="color: red; font-size: 18px;">Interprétation des Co-Occurrences d'Entités Nommées de Types Différents</h3>
#     <!-- Introduction -->
#     <p>
#         Les résultats de l'analyse des co-occurrences d'entités nommées de types différents dans nos documents sont présentés ci-dessous :
#     </p>
#     <!-- Commentaire général -->
#     <p>
#         Les paires d'entités nommées de types différents illustrent les relations potentielles entre des entités de nature distincte dans nos articles. L'analyse de ces co-occurrences peut nous aider à identifier des liens intéressants entre des sujets, des personnes, ou des entités de différentes catégories.
#     </p>
#     <!-- Détail des paires d'entités les plus fréquentes -->
#     <h4>Paires d'entités de types différents les plus fréquentes :</h4>
#     <ul>
#         <li><strong>Paire d'entités : 'Covid-19' et 'JT'</strong> - Fréquence : 64</li>
#         <li><strong>Paire d'entités : 'Angela Merkel' et 'Allemagne'</strong> - Fréquence : 62</li>
#         <li><strong>Paire d'entités : 'Covid-19' et 'France'</strong> - Fréquence : 55</li>
#         <li><strong>Paire d'entités : 'Covid-19' et 'Covid-19'</strong> - Fréquence : 53</li>
#         <li><strong>Paire d'entités : 'Emmanuel Macron' et 'franceinfo'</strong> - Fréquence : 48</li>
#         <li><strong>Paire d'entités : 'Emmanuel Macron' et 'France'</strong> - Fréquence : 45</li>
#         <li><strong>Paire d'entités : 'Emmanuel Macron' et 'la France'</strong> - Fréquence : 41</li>
#         <li><strong>Paire d'entités : 'Laurent Desbonnets' et 'Berlin'</strong> - Fréquence : 41</li>
#         <li><strong>Paire d'entités : 'Laurent Desbonnets' et 'JT'</strong> - Fréquence : 41</li>
#         <li><strong>Paire d'entités : 'Emmanuel Macron' et 'JT'</strong> - Fréquence : 40</li>
#     </ul>
#     <!-- Commentaire sur les paires -->
#     <p>
#         Les paires d'entités nommées de types différents les plus fréquentes révèlent des associations intéressantes dans nos articles. Par exemple, la paire 'Covid-19' et 'JT' apparaît ensemble 64 fois, ce qui suggère que les articles mentionnent fréquemment des reportages télévisés sur la pandémie. De même, 'Angela Merkel' et 'Allemagne' avec 62 co-occurrences suggèrent une relation étroite entre la chancelière allemande et son pays.
#     </p>
#     <!-- Observations -->
#     <p>
#         Ces co-occurrences peuvent être exploitées pour une analyse plus approfondie des relations entre les entités dans nos articles, ce qui pourrait révéler des tendances, des connexions inattendues ou des sujets récurrents.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 12 : Analyse des Co-Occurrences d'Entités Nommées au Sein d'une Même Phrase</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette section, nous approfondissons notre analyse des co-occurrences d'entités nommées, en nous limitant aux cas où ces entités apparaissent dans une même phrase au sein de nos documents. L'objectif est d'examiner de manière plus précise les relations entre les entités nommées qui interagissent au niveau de la phrase.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour réaliser cette analyse, nous exploitons les informations fournies par spaCy, notre bibliothèque de traitement du langage naturel. Nous identifions les entités nommées dans chaque phrase des documents et relevons les cas où deux entités nommées de types différents se co-occurrent dans la même phrase.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les résultats de cette analyse nous permettent de mettre en lumière les relations spécifiques qui se manifestent au niveau de la phrase. Nous commentons ces résultats pour identifier des associations intéressantes entre différentes entités nommées, ce qui peut contribuer à une meilleure compréhension des informations contenues dans nos documents.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les exemples suivants illustrent les informations dont nous disposons pour chaque résultat issu de l'analyse d'un texte par spaCy :
# </p>
#
# <!-- Insérez ici les exemples de code spaCy fournis dans la question pour illustrer les informations disponibles pour chaque résultat -->
#
# </body>
# </html>

# %%
# Charger le modèle en français
nlp = spacy.load("fr_core_news_md")

# Fonction pour analyser les co-occurrences d'entités nommées dans une phrase
def analyze_entity_cooccurrences(sentence):
    # Traiter la phrase avec spaCy
    doc = nlp(sentence)
    
    # Initialiser un dictionnaire pour stocker les co-occurrences d'entités
    entity_cooccurrences = {}
    
    # Parcourir les entités nommées dans la phrase
    entities_in_sentence = [ent for ent in doc.ents]
    
    for i, entity1 in enumerate(entities_in_sentence):
        for j, entity2 in enumerate(entities_in_sentence):
            # Ne pas comparer une entité avec elle-même
            if i != j:
                # Trier les entités par ordre de début
                entity1, entity2 = sorted([entity1, entity2], key=lambda ent: ent.start)
                
                # Clé unique pour la paire d'entités
                entity_pair_key = (entity1.text, entity2.text)
                
                # Vérifier si la paire d'entités existe dans le dictionnaire
                if entity_pair_key in entity_cooccurrences:
                    entity_cooccurrences[entity_pair_key] += 1
                else:
                    entity_cooccurrences[entity_pair_key] = 1
    
    return entity_cooccurrences

# Exemple de phrase pour l'analyse
example_sentence = "La chancelière Angela Merkel a rencontré le président Emmanuel Macron à Paris."

# Appeler la fonction pour analyser les co-occurrences dans la phrase
entity_cooccurrences = analyze_entity_cooccurrences(example_sentence)

# Afficher les résultats
for entity_pair, cooccurrence_count in entity_cooccurrences.items():
    print(f"Paire d'entités : '{entity_pair[0]}' et '{entity_pair[1]}' - Fréquence : {cooccurrence_count}")
# Out:
# Paire d'entités : 'Angela Merkel' et 'Emmanuel Macron' - Fréquence : 3
# Paire d'entités : 'Angela Merkel' et 'Paris' - Fréquence : 3

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <!-- Titre de la section -->
#     <h3 style="color: red; font-size: 18px;">Interprétation des Co-Occurrences d'Entités Nommées de Types Différents dans une Même Phrase</h3>
#     <!-- Introduction -->
#     <p>
#         Les résultats de l'analyse des co-occurrences d'entités nommées de types différents au sein d'une même phrase sont présentés ci-dessous :
#     </p>
#     <!-- Commentaire général -->
#     <p>
#         Cette analyse se concentre sur les paires d'entités nommées de types différents qui coïncident dans une même phrase, ce qui peut indiquer des relations ou des liens significatifs entre ces entités de nature différente dans le contexte d'une phrase spécifique.
#     </p>
#     <!-- Détail des paires d'entités les plus fréquentes -->
#     <h4>Paires d'entités de types différents les plus fréquentes dans une Même Phrase :</h4>
#     <ul>
#         <li><strong>Paire d'entités : 'Angela Merkel' et 'Emmanuel Macron'</strong> - Fréquence : 3</li>
#         <li><strong>Paire d'entités : 'Angela Merkel' et 'Paris'</strong> - Fréquence : 3</li>
#     </ul>
#     <!-- Commentaire sur les paires -->
#     <p>
#         Les paires d'entités nommées de types différents les plus fréquentes dans une même phrase suggèrent des associations spécifiques dans le contexte de ces phrases particulières. Par exemple, la paire 'Angela Merkel' et 'Emmanuel Macron' apparaît ensemble 3 fois dans une même phrase, ce qui peut indiquer que ces deux personnalités sont mentionnées conjointement dans le contexte de ces phrases. De même, 'Angela Merkel' et 'Paris' coïncident également 3 fois, suggérant une association particulière entre la chancelière allemande et la ville de Paris au sein de ces phrases.
#     </p>
#     <!-- Observations -->
#     <p>
#         L'analyse des co-occurrences d'entités nommées de types différents dans une même phrase peut fournir des informations contextuelles importantes sur les relations entre les entités dans des contextes spécifiques, ce qui peut être utile pour comprendre les sujets ou les événements liés à ces co-occurrences.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 13 : Caractérisation des Relations entre Entités Nommées</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour caractériser de manière simple la relation entre deux entités, nous nous sommes intéressés au contexte dans lequel les deux entités apparaissent ensemble. Notre objectif était de trouver quelques relations qui peuvent être caractérisées par un verbe. Pour ce faire, nous avons développé une fonction personnalisée en utilisant spaCy, notre bibliothèque de traitement du langage naturel.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Voici comment fonctionne la fonction que nous avons créée :
# </p>
#
# <ol style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li>Nous parcourons les articles de notre base de données et leurs entités pour identifier les paires d'entités dont la fréquence de co-occurrence est élevée.</li>
#     <li>Ensuite, nous recherchons les phrases dans ces articles où ces paires d'entités apparaissent ensemble.</li>
#     <li>Nous utilisons spaCy pour traiter ces phrases et nous identifions les verbes qui apparaissent entre les deux entités.</li>
#     <li>Les verbes sont lemmatisés pour obtenir leur forme de base.</li>
#     <li>Enfin, nous compilons une liste des verbes qui caractérisent les relations entre les entités.</li>
# </ol>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Cette approche nous permet de caractériser la relation de manière un peu naïve en se basant sur le verbe qui relie les entités. En pratique, l'analyse syntaxique peut être utilisée pour caractériser la nature de la relation de manière plus fine.
# </p>
#
# <!-- Insérez ici des exemples de résultats obtenus grâce à cette méthode -->
#
# </body>
# </html>

# %%
# Fonction pour extraire les verbes entre deux entités dans la même phrase
def extract_verbs_between_entities(entity1, entity2, entity_type1, entity_type2):
    # Initialiser une liste pour stocker les phrases contenant les deux entités
    sentences_with_entities = []
    
    # Parcourir les articles et leurs entités
    for article_url, article_entities in articles_entities.items():
        # Vérifier si les deux entités de types correspondants apparaissent dans la même phrase
        if any(entity["text"] == entity1 and entity["type"] == entity_type1 for entity in article_entities) \
            and any(entity["text"] == entity2 and entity["type"] == entity_type2 for entity in article_entities):
            # Extraire la phrase contenant les entités
            article_content = database[article_url]['content']
            doc = nlp(article_content)
            for sentence in doc.sents:
                sentence_entities = [entity["text"] for entity in article_entities if entity["text"] in sentence.text]
                if entity1 in sentence_entities and entity2 in sentence_entities:
                    sentences_with_entities.append(sentence.text)
    
    # Traiter les phrases avec spaCy pour extraire les verbes entre les entités
    verbs_between = []
    for sentence in sentences_with_entities:
        doc = nlp(sentence)
        for token in doc:
            if token.pos_ == "VERB":
                verbs_between.append(token.lemma_)
    
    return verbs_between

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 14 : Exemples de Couples d'Entités et Verbes Associés</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Dans cette section, nous présentons des exemples de couples d'entités et de verbes associés qui ont du sens et qui ont été identifiés à l'aide de notre fonction personnalisée. Ces exemples illustrent comment nous pouvons caractériser les relations entre les entités en utilisant les verbes qui les relient.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Voici deux exemples que nous avons pris pour illustrer notre approche :
# </p>
#
# <ol style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <li><strong>Exemple 1 :</strong> Nous avons pris les entités "Angela Merkel" et "Emmanuel Macron", qui sont de type "PERSONNES". En utilisant notre fonction, nous avons identifié les verbes qui relient ces entités, ce qui peut nous donner des informations sur la relation entre ces deux personnalités.</li>
#     <li><strong>Exemple 2 :</strong> Nous avons pris les entités "Covid-19" et "France", qui sont respectivement de type "PERSONNES" et "LIEUX". En analysant les verbes entre ces entités, nous pouvons comprendre comment la France est liée à la pandémie de Covid-19.</li>
# </ol>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Ces exemples démontrent comment notre approche peut être utilisée pour caractériser des relations spécifiques entre les entités nommées en se basant sur les verbes qui apparaissent entre elles.
# </p>
#
# <!-- Insérez ici les résultats obtenus pour chaque exemple -->
#
# </body>
# </html>

# %%
# Exemples de couples d'entités et verbes associés qui font sens
entity1 = "Angela Merkel"
entity2 = "Emmanuel Macron"
entity_type1 = "PER"
entity_type2 = "PER"
verbs_between = extract_verbs_between_entities(entity1, entity2, entity_type1, entity_type2)
print(f"Verbes entre les entités : {verbs_between}")
# Out:
# Verbes entre les entités : ['entretenir', 'appeler', 'tenter', 'débloquer', 'permettre', 'mobiliser', 'redresser', 'assurer', 'repousser', 'aller', 'continuer', 'échanger', 'proposer', 'être', 'décider', 'aller', 'lever', 'détailler', 'mutualiser', 'vouloir', 'entendre', 'parler', 'pose', 'entretenir', 'faire', 'proposer', 'redistribuer', 'sinistrer', 'covid-19', 'poursuivre', 'proposer', 'plonger', 'suivre', 'soutenir', 'rétablir', 'renforcer', 'soutenir', 'souligner', 'pose', 'présenter', 'présenter', 'revenir', 'proposer', 'croire', 'penser', 'accorder', 'railler', 'expliquer', 'présenter', 'convier', 'aller', 'payer', 'pouvoir', 'sauver', 'mettre', 'voir', 'avoir', 'refouler', 'refouler', 'déplorer', 'présenter', 'conditionner', 'présenter', 'alléger', 'estime', 'insoumis', 'présenter']

# %%
# Exemples de couples d'entités et verbes associés qui font sens
entity1 = "Covid-19"
entity2 = "France"
entity_type1 = "PER" 
entity_type2 = "LOC"
verbs_between = extract_verbs_between_entities(entity1, entity2, entity_type1, entity_type2)
print(f"Verbes entre les entités : {verbs_between}")
# Out:
# Verbes entre les entités : ['enregistrer', 'lier', 'covid-19', 'covid-19', 'covid-19', 'chuter', 'aide', 'essuyer', 'avoir', 'covid-19', 'mourir', 'covid-19', 'contaminer', 'affirmer', 'avoir', 'jouer', 'traverser', 'covid-19', 'suivre', 'appeler', 'verser', 'rendre', 'publier', 'soutenir', 'mobiliser', 'covid-19', 'franchir', 'tuer', 'covid-19', 'covid-19', 'prolonger', 'annoncer', 'rouvrir', 'commencer', 'ressentir', 'covid-19', 'interrompre', 'covid-19', 'aller', 'accorder', 'covid-19', 'annoncer', 'rapporter', 'aller', 'accorder', 'covid-19', 'annoncer', 'analyser', 'lutter', 'retenir', 'nourrir', 'rejeter', 'confirmer', 'sommer', 'restreindre', 'mettre', 'lutter', 'covid-19', 'rejeter', 'confirmer', 'sommer', 'restreindre', 'mettre', 'lutter', 'covid-19', 'compte', 'covid-19', 'publier', 'covid-19', 'reste', 'circuler', 'pouvoir', 'partir', 'assurer', 'covid-19', 'souffrir', 'annoncer', 'entrer', 'affaiblir', 'provoquer', 'covid-19', 'confirmer', 'gagner', 'confronter', 'déclare
# ...

# %%
# Exemples de couples d'entités et verbes associés qui font sens
entity1 = "Union européenne"   
entity2 = "Brexit"
entity_type1 = "ORG" 
entity_type2 = "ORG"
verbs_between = extract_verbs_between_entities(entity1, entity2, entity_type1, entity_type2)
print(f"Verbes entre les entités : {verbs_between}")
# Out:
# Verbes entre les entités : ['donner', 'rêver', 'rester', 'faire', 'sonner', 'titiller', 'aller', 'sonner', 'célébrer', 'réclamer', 'sonner', 'sonner', 'sonner', 'continuer', 'déchirer', 'confronter', 'marquer', 'sonner', 'vouloir', 'marque', 'embarrasser', 'fier', 'avoir', 'attaquer', 'entendre', 'préparer', 'post-brexit', 'sauvegarder', 'convoquer', 'anticiper', 'ouvrir', 'post-brexit', 'mettre', 'constituer', 'croiser', 'post-brexit', 'mener', 'baptiser', 'annoncer', 'surestimer', 'quitter', 'argumenter', 'expliquer', 'passer', 'retentir', 'souhaiter', 'quitter', 'apprendre', 'installer', 'rebaptiser', 'devenir', 'savoir', 'regarder', 'confier', 'aller', 'pleurer', 'vouloir', 'rester', 'admettre', 'quitte', 'expliquer', 'réserve', 'situer', 'devenir', 'voter', 'déboucher', 'dire', 'être', 'aller', 'prendre', 'finaliser', 'avoir', 'aller', 'devenir', 'être', 'indique', 'quitte', 'estime', 'sauter', 'avoir', 'avoir', 'négocier', 'régler', 'attrister', 'espérer', 'sortir', 'aller', 'p
# ...

# %% [markdown]
# <div style="font-family: 'Arial', sans-serif; color: #333; font-size: 14px; margin-top: 20px;">
#     <!-- Titre de la section -->
#     <h3 style="color: red; font-size: 18px;">Interprétation des Couples d'Entités et Verbes Associés</h3>
#     <!-- Introduction -->
#     <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#         Les exemples suivants présentent des couples d'entités nommées de types différents ainsi que les verbes associés qui font sens dans le contexte des phrases où ces couples apparaissent :
#     </p>
#     <!-- Exemple 1 -->
#     <h4>Exemple 1 :</h4>
#     <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#         Pour le couple d'entités 'Angela Merkel' et 'Emmanuel Macron' de type 'Personne', les verbes associés qui font sens dans le contexte des phrases où ils apparaissent incluent 'entretenir', 'appeler', 'tenter', et d'autres. Ces verbes suggèrent des interactions ou des relations potentielles entre les deux personnalités.
#     </p>
#     <!-- Exemple 2 -->
#     <h4>Exemple 2 :</h4>
#    <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#         Pour le couple d'entités 'Covid-19' et 'France' où 'Covid-19' est de type 'Personne' et 'France' est de type 'Lieu', les verbes associés incluent 'enregistrer', 'lier', 'chuter', 'contaminer', 'franchir', et d'autres. Ces verbes suggèrent des actions ou des événements liés à la pandémie Covid-19 en relation avec le pays France.
#     <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     <!-- Exemple 3 -->
#     <h4>Exemple 3 :</h4>
#     <p>
#         Pour le couple d'entités 'Union européenne' et 'Brexit' de type 'Organisation', les verbes associés qui font sens dans le contexte des phrases où ils apparaissent incluent 'donner', 'rêver', 'continuer', 'mener', 'expliquer', 'espérer', et d'autres. Ces verbes suggèrent des actions, des émotions ou des discours liés à la relation entre l'Union européenne et le Brexit.
#     </p>
#     <!-- Observations -->
#     <p>
#         L'analyse des couples d'entités et des verbes associés permet de mettre en lumière les relations potentielles entre différentes entités nommées de types différents dans le contexte des phrases. Cette approche peut aider à identifier des associations intéressantes, des actions spécifiques, des émotions ou des discours liés à ces entités dans le corpus de textes analysés.
#     </p>
# </div>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 15 : Utilisation des Couples d'Entités et de Verbes</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Les couples d'entités et de verbes identifiés précédemment sont une ressource précieuse pour découvrir de nouvelles relations entre les entités nommées et pour regrouper des relations similaires.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En utilisant ces couples, nous pouvons rechercher de nouvelles relations dans nos documents en examinant les verbes qui relient différentes entités. Par exemple, si nous identifions plusieurs couples d'entités liées par le verbe "travailler", cela pourrait indiquer des relations professionnelles entre ces entités.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     De plus, en regroupant des relations similaires basées sur les verbes, nous pouvons créer des catégories de relations. Par exemple, tous les couples d'entités liés par des verbes tels que "diriger", "gérer" et "superviser" pourraient être regroupés sous la catégorie "relations de gestion".
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Ces regroupements permettent une meilleure organisation des informations extraites de nos documents, ce qui peut être utile pour la génération de résumés, l'analyse de tendances ou la recherche d'informations spécifiques.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En résumé, les couples d'entités et de verbes nous offrent un moyen puissant d'explorer et de structurer les relations entre les entités nommées dans nos textes.
# </p>
#
# <!-- Vous pouvez ajouter d'autres éléments visuels ou des exemples supplémentaires si nécessaire -->
#
# </body>
# </html>

# %% [markdown]
# <br/>
# <hr style="border-width:6px;border-color:#75DFC1">
# <center><h1>QUESTION 16 : Affiner l'Analyse avec l'Arbre de Dépendance Syntaxique</h1></center>
# <hr style="border-width:6px;border-color:#75DFC1">
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Pour affiner davantage notre analyse des relations entre les entités nommées, nous pouvons tirer parti de l'arbre de dépendance syntaxique fourni par spaCy.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     L'arbre de dépendance syntaxique représente les relations grammaticales entre les mots d'une phrase, y compris les verbes, les sujets, les objets, etc. En l'utilisant, nous pouvons identifier plus précisément les rôles des entités nommées dans une phrase.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     Par exemple, si nous identifions une relation entre deux entités nommées et que l'arbre de dépendance révèle qu'un verbe tel que "travailler" est le noyau de la phrase et que l'une des entités est le sujet tandis que l'autre est l'objet direct, cela renforce la notion de relation professionnelle.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     De plus, en utilisant l'arbre de dépendance, nous pouvons examiner les modificateurs et les compléments des entités nommées pour obtenir des informations contextuelles plus riches. Par exemple, si nous identifions un couple d'entités liées par le verbe "habiter" et que l'arbre de dépendance indique que l'une des entités est précédée de "à Paris", cela indique un lieu de résidence.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En intégrant l'arbre de dépendance syntaxique dans notre analyse, nous pouvons non seulement caractériser les relations entre les entités, mais aussi préciser la nature de ces relations et obtenir des détails contextuels importants.
# </p>
#
# <p style="font-family: 'Arial', sans-serif; font-size: 14px;">
#     En conclusion, l'utilisation de l'arbre de dépendance syntaxique nous permet d'affiner notre analyse des relations entre les entités nommées, ce qui peut être précieux pour une compréhension plus approfondie du contenu de nos documents.
# </p>
#
# <!-- Vous pouvez ajouter d'autres éléments visuels ou des exemples supplémentaires si nécessaire -->
#
# </body>
# </html>
